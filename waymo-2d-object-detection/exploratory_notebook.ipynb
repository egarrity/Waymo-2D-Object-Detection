# %%
import os
import sys
import time
import argparse


import numpy as np
import torch.nn as nn
import torch.utils.data

from model.centernet import get_hourglass

from model.utils.utils import _tranpose_and_gather_feature, load_model
from model.utils.image import transform_preds
from model.utils.losses import _neg_loss, _reg_loss
from model.utils.summary import create_summary, create_logger, create_saver, DisablePrint
from model.utils.post_process import ctdet_decode

# %%
# instantiate model
model = get_hourglass['large_hourglass']
model
# Out:
# exkp(
#   (pre): Sequential(
#     (0): convolution(
#       (conv): Conv2d(3, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): residual(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (skip): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
# ...
